# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'D:\SYNCNER TRAINING\BOOTCAMP\Day 3\Task 4\hapiscore_whr.csv')
df.set_index("country", inplace=True)
df = df.transpose()
df
# Out:
# country  Afghanistan  Angola  Albania   UAE  Argentina  Armenia  Australia  \
# 2005             NaN     NaN      NaN   NaN        NaN      NaN       73.4
# 2006             NaN     NaN      NaN  67.3       63.1     42.9        NaN
# 2007             NaN     NaN     46.3   NaN       60.7     48.8       72.8
# 2008            37.2     NaN      NaN   NaN       59.6     46.5       72.5
# 2009            44.0     NaN     54.9  68.7       64.2     41.8        NaN
# 2010            47.6     NaN     52.7  71.0       64.4     43.7       74.5
# 2011            38.3    55.9     58.7  71.2       67.8     42.6       74.1
# 2012            37.8    43.6     55.1  72.2       64.7     43.2       72.0
# 2013            35.7    39.4     45.5  66.2       65.8     42.8       73.6
# 2014            31.3    38.0     48.1  65.4       66.7     44.5       72.9
# 2015            39.8     NaN     46.1  65.7       67.0     43.5       73.1
# ...

# %%
df = df.iloc[:, :10]
df
# Out:
# country  Afghanistan  Angola  Albania   UAE  Argentina  Armenia  Australia  \
# 2005             NaN     NaN      NaN   NaN        NaN      NaN       73.4
# 2006             NaN     NaN      NaN  67.3       63.1     42.9        NaN
# 2007             NaN     NaN     46.3   NaN       60.7     48.8       72.8
# 2008            37.2     NaN      NaN   NaN       59.6     46.5       72.5
# 2009            44.0     NaN     54.9  68.7       64.2     41.8        NaN
# 2010            47.6     NaN     52.7  71.0       64.4     43.7       74.5
# 2011            38.3    55.9     58.7  71.2       67.8     42.6       74.1
# 2012            37.8    43.6     55.1  72.2       64.7     43.2       72.0
# 2013            35.7    39.4     45.5  66.2       65.8     42.8       73.6
# 2014            31.3    38.0     48.1  65.4       66.7     44.5       72.9
# 2015            39.8     NaN     46.1  65.7       67.0     43.5       73.1
# ...

# %%
plt.figure(figsize=(10, 3))
for country in df.columns:
    plt.plot(df.index, df[country], marker="o", linestyle="-", linewidth=1, label=country)
plt.ylabel("Happiness Score", fontsize=12)  # Corrected y-axis label
plt.xlabel("Years", fontsize=12)
plt.title("Happiness Over Time (First 10 Countries)", fontsize=14, fontweight="bold")
plt.grid(True, linestyle="--", alpha=0.5)
plt.legend(loc="best", fontsize=4)
plt.tight_layout()
plt.show()
